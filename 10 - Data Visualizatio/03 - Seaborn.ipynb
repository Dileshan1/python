# %% [markdown]
# # Importing seaborn

# %%
import seaborn as sns
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Numerical data

# %% [markdown]
# # Line charts

# %%
x=np.arange(100)
y=np.random.normal(20,3,100)
sns.lineplot(x,y)
plt.title("Simple line chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df=pd.DataFrame({"Year":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000],
                 "Weight":[76,64,65,70,78,79,75,74,69,68,65],
                "Height":[167,168,168,168,169,170,171,171,172,173,174]})
df
# Out:
#     Year  Weight  Height
# 0   1990      76     167
# 1   1991      64     168
# 2   1992      65     168
# 3   1993      70     168
# 4   1994      78     169
# 5   1995      79     170
# 6   1996      75     171
# 7   1997      74     171
# 8   1998      69     172
# 9   1999      68     173
# 10  2000      65     174

# %%
sns.lineplot(data=df,x="Year",y="Weight")
plt.title("Weight with years")
plt.xlabel("Year")
plt.ylabel("Weight")
plt.show()

# %%
sns.lineplot(data=df,x="Year",y="Weight")
sns.lineplot(data=df,x="Year",y="Height")
plt.title("Weight with years")
plt.xlabel("Year")
plt.ylabel("Weight")
plt.show()

# %% [markdown]
# # Histogram

# %%
age=np.random.randint(10,100,500)

sns.histplot(age)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
age=np.random.randint(10,100,500)
sns.distplot(age)                    # this plot gives density carve
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
weight=np.random.normal(50,3,500)
sns.distplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
titanic = sns.load_dataset("titanic")           # inbuild data set in seaborn libary
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.distplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Boxplot

# %%
weight=np.random.normal(50,3,500)
sns.boxplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Boxenplot
# **this same as boxplot, only difference is visual**

# %%
weight=np.random.normal(50,3,500)
sns.boxenplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxenplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Violin plot (combination of histrogram and boxplot)

# %%
weight=np.random.normal(50,3,500)
sns.violinplot(weight)
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
weight=np.random.normal(50,3,500)
sns.violinplot(weight,inner=None)       # unsing "inner" we can remove boxplt in the violinplot
plt.title("Weight Distribution")
plt.xlabel("Weight spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.violinplot(titanic["age"])
plt.title("Age Distribution")
plt.xlabel("Age spread")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Categorical data

# %% [markdown]
# # Bar graphs

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %% [markdown]
# # Vertical

# %%
sns.barplot(data=df,x="Gender",y="Number_of_Students")
plt.title("Counts for Gender")
plt.show()

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
g=titanic.groupby("sex")["sex"].count()
df=pd.DataFrame(g)
df.columns=["Count"]
df.reset_index(inplace=True)
df
# Out:
#       sex  Count
# 0  female    314
# 1    male    577

# %%
sns.barplot(data=df,x="sex",y="Count")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Horizontal

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %%
sns.barplot(data=df,y="Gender",x="Number_of_Students")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Counting the categories

# %%
# in here we no need to create df_new for count of catagorical variable

# %%
df=pd.DataFrame({"Gender":["Male","Female","Male","Male","Female","Male"],"Age":[34,57,35,54,56,32]})
df
# Out:
#    Gender  Age
# 0    Male   34
# 1  Female   57
# 2    Male   35
# 3    Male   54
# 4  Female   56
# 5    Male   32

# %%
sns.countplot("Gender",data=df)
plt.title("Count for Gender")
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# **Pie chart is not available in seaborn library**

# %% [markdown]
# # Bar plot using catplot

# %%
sns.catplot(data=df, x="Gender", kind="count")
plt.show()

# %%
df=pd.DataFrame({"Gender":["Male","Female"],"Number_of_Students":[34,57]})
df
# Out:
#    Gender  Number_of_Students
# 0    Male                  34
# 1  Female                  57

# %%
sns.catplot(data=df,x="Gender",y="Number_of_Students",kind="bar")
plt.title("Counts for Gender")
plt.show()

# %% [markdown]
# # Categorical VS Numerical using catplot

# %% [markdown]
# # Categorical scatter plots

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int")})
df.head()
# Out:
#    Gender  Age
# 0  Female   42
# 1    Male   31
# 2    Male   37
# 3    Male   33
# 4    Male   39

# %%
sns.catplot(data=df,x="Gender",y="Age")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",jitter=False)
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",jitter=False,order=["Male","Female"])
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Swarm plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="swarm")
plt.title("Age VS Gender")
plt.show()

# %%
sns.swarmplot(data=df,x="Gender",y="Age")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Represent another category

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int"),
                 "Class":np.random.choice(a=["A","B","C"],size=100)})
df.head()
# Out:
#    Gender  Age Class
# 0  Female   30     B
# 1    Male   31     C
# 2    Male   31     B
# 3  Female   24     A
# 4    Male   35     A

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="swarm",hue="Class")             # "hue" help to represent another category
plt.title("Age VS Gender")
plt.show()

# %%
sns.swarmplot(data=df,x="Gender",y="Age",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Changing to horizontal

# %%
sns.catplot(data=df,y="Gender",x="Age",kind="swarm",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Side by side boxplots

# %%
df=pd.DataFrame({"Gender":np.random.choice(a=["Male", "Female"],size=100),
                 "Age":np.round(np.random.normal(30,5,100)).astype("int"),
                 "Class":np.random.choice(a=["A","B","C"],size=100)})
df.head()
# Out:
#    Gender  Age Class
# 0  Female   21     A
# 1  Female   34     B
# 2  Female   35     B
# 3  Female   33     A
# 4  Female   27     A

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box",hue="Class")
plt.title("Age VS Gender")
plt.show()

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="box",hue="Class",dodge=False)
plt.title("Age VS Gender")
plt.show()

# %%
sns.boxplot(data=df, y="Age", x="Gender", hue="Class")
plt.show()

# %% [markdown]
# # Side by side boxen plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="boxen")
plt.title("Age VS Gender")
plt.show()

# %%
sns.boxenplot(data=df, y="Age", x="Gender")
plt.show()

# %%
sns.catplot(data=df, y="Age", x="Gender", kind="boxen", hue="Class")
plt.show()

# %% [markdown]
# # Side by side violin plots

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="violin")
plt.title("Age VS Gender")
plt.show()

# %%
sns.violinplot(data=df, y="Age", x="Gender")
plt.show()

# %%
sns.catplot(data=df, y="Age", x="Gender", kind="violin", hue="Class")
plt.show()

# %% [markdown]
# # Swarm & violin plots together

# %%
g=sns.catplot(data=df,x="Gender",y="Age",kind="violin",inner=None)
sns.swarmplot(data=df,x="Gender",y="Age",ax=g.ax,color="black")
plt.title("Age VS Gender")
plt.show()

# %% [markdown]
# # Bar graphs for averages with categorical data

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",kind="bar")
plt.title("Age with Gender")
plt.show()

# %% [markdown]
# # Comparing one numerical variable with two categorical variables

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",hue="alive",kind="bar")
plt.title("Age with Gender")
plt.show()

# %% [markdown]
# # Point charts for averages with categorical data

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x="sex",y="age",kind="point")
plt.title("Age with Gender")
plt.show()

# %%
sns.pointplot(data=titanic, x="sex", y="age")
plt.show()

# %%
sns.catplot(data=titanic,x="sex",y="age",hue="alive",kind="point")
plt.title("Age with Gender")
plt.show()

# %%
sns.pointplot(data=titanic, x="sex", y="age", hue="alive")
plt.show()

# %% [markdown]
# # Categorical VS Categorical data using catplot

# %% [markdown]
# # Multiple bar graphs

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x="sex", kind="count", hue="alive", data=titanic)
plt.title("Death status with Gender")
plt.show()

# %% [markdown]
# # Numerical VS Numerical data using catplot

# %% [markdown]
# # Scatter plots

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
plt.title("Tips VS Total Bill")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex")
plt.title("Tips VS Total Bill")
plt.show()

# %% [markdown]
# # Bubble plots (Comparing 3 numerical variables)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill",  y="tip",size="size",hue="sex")
plt.title("Tips VS Total Bill")
plt.show()

# %% [markdown]
# # Pair plots

# %%
titanic = sns.load_dataset("titanic")
df=titanic[["age","fare"]]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(titanic)        # in this case all number columns(female 0, male 1, age/numaric, category represent by number(0,1))
plt.show()                   # all are ploted
                             # therefore we need to rebuild data frame in only numeric data
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
df=pd.DataFrame({"val1":np.random.random(100),"val2":np.random.randn(100),"val3":np.random.normal(50,2,100)})
df.head()
# Out:
#        val1      val2       val3
# 0  0.192298 -0.122562  50.939833
# 1  0.320339  0.280998  46.815267
# 2  0.582727  0.825941  49.092675
# 3  0.640414  1.650294  47.549802
# 4  0.671074 -0.030956  48.705967

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Heat maps

# %%
df=pd.DataFrame({"Loc1":[0,10,0],"Loc2":[10,0,15],"Loc3":[20,15,0]},index=["Loc1","Loc2","Loc3"])
df
# Out:
#       Loc1  Loc2  Loc3
# Loc1     0    10    20
# Loc2    10     0    15
# Loc3     0    15     0

# %%
sns.heatmap(df,annot=True)
plt.show()

# %% [markdown]
# ## Heatmap for correlation

# %%
titanic = sns.load_dataset("titanic")
df=titanic[["age","fare"]]
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df.corr()
# Out:
#            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1)
plt.show()

# %%
df=pd.DataFrame({"val1":np.random.random(100),"val2":np.random.randn(100),"val3":np.random.normal(50,2,100), "val4":np.random.random(100),"val5":np.random.randn(100),"va63":np.random.normal(50,2,100)}, )
df.head()
# Out:
#        val1      val2       val3      val4      val5       va63
# 0  0.180840  1.210490  48.029053  0.418829  0.938138  49.411997
# 1  0.418961 -0.344052  51.798625  0.624245  2.245300  49.606785
# 2  0.587137 -1.337460  52.846372  0.596378  1.334418  50.276858
# 3  0.188371  1.196889  49.272082  0.856324  1.342721  48.251204
# 4  0.225534 -2.251202  49.450026  0.029304  0.677777  51.611599

# %%
df.corr()
# Out:
#           val1      val2      val3      val4      val5      va63
# val1  1.000000  0.014312 -0.143704  0.037562  0.172307  0.004280
# val2  0.014312  1.000000 -0.043534  0.173281  0.072804  0.002143
# val3 -0.143704 -0.043534  1.000000 -0.175543  0.032291 -0.135850
# val4  0.037562  0.173281 -0.175543  1.000000  0.149730 -0.115394
# val5  0.172307  0.072804  0.032291  0.149730  1.000000 -0.025509
# va63  0.004280  0.002143 -0.135850 -0.115394 -0.025509  1.000000

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(df.corr(), annot = True, vmin = -1, vmax = 1)
plt.show()
